# %% [markdown]
# ## OpenAI /ChatGPT— How to Use it With Python
#
# ![ss](https://miro.medium.com/v2/resize:fit:720/format:webp/1*d-YRTQiEje6nKFfws6aVIQ.png)

# %% [markdown]
# ### https://github.com/openai/openai-python#openai-python-library

# %%
import openai
openai
# Out:
# <module 'openai' from 'C:\\Users\\Vicky\\anaconda3\\lib\\site-packages\\openai\\__init__.py'>

# %% [markdown]
# ### https://stackoverflow.com/a/75898717/11493297
#
#     Is there a limit for OpenAI?
#
#     Limit: 20.000000 / min. Current: 24.000000 / min.
#     If you hit a rate limit, it means you've made too many
#     requests in a short period of time, and the API is
#     refusing to fulfill further requests until
#     a specified amount of time has passed.
#
# #### https://platform.openai.com/docs/guides/rate-limits/overview

# %%
API_Key = '**********************************'
openai.api_key = API_Key

# %% [markdown]
# ### https://platform.openai.com/account/api-keys

# %%
# list models
models = openai.Model.list()
models
# Out:
# <OpenAIObject list at 0x213ce412e50> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1677610602,
#       "id": "gpt-3.5-turbo",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
# print the first model's id
print(models.data[0].id)
# Out:
# babbage

# %%
# Image generation (DALL·E)

image_resp = openai.Image.create(prompt="two dogs playing chess, oil painting", 
                                 n=4, size="512x512")
print(image_resp)
# Out:
# {
#   "created": 1680876764,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Z0Thpnv9nStuAJE5dKhhHd8U/user-Vpy5qef3GlLla8gB3yTDThit/img-aTZJkMVPHMMM55L3yvpcqh3E.png?st=2023-04-07T13%3A12%3A44Z&se=2023-04-07T15%3A12%3A44Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-06T20%3A44%3A23Z&ske=2023-04-07T20%3A44%3A23Z&sks=b&skv=2021-08-06&sig=0bR4mINWRl5JwohuVqd8t4lLUPDfMGB6dVdJQ1PjMiM%3D"
#     },
#     {
# ...

# %%
openai.Image.create(prompt="human face, pencil sketch", n=5, size="512x512")
# Out:
# <OpenAIObject at 0x213cec13d60> JSON: {
#   "created": 1680877131,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Z0Thpnv9nStuAJE5dKhhHd8U/user-Vpy5qef3GlLla8gB3yTDThit/img-vUZCe1YrqmYn2UTymvEUaJYD.png?st=2023-04-07T13%3A18%3A51Z&se=2023-04-07T15%3A18%3A51Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-06T20%3A45%3A22Z&ske=2023-04-07T20%3A45%3A22Z&sks=b&skv=2021-08-06&sig=qZN1dLAX5%2BpfbGb10opLlnXPjkR55nxN2xyaVr/bVkY%3D"
#     },
#     {
# ...

# %%
completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", 
                messages=[{"role": "user", "content": "What is OpenAI"}])
print(completion.choices[0].message.content)
# Out:
# OpenAI is an artificial intelligence (AI) research laboratory consisting of the world's leading AI researchers, engineers, and computer scientists. It was founded in December 2015 by a group of entrepreneurs, including Tesla CEO Elon Musk, with the aim of developing technologies that can benefit humanity in a safe and beneficial manner. OpenAI focuses on research in various areas of AI, ranging from natural language processing to robotics, and aims to develop AI systems that are trustworthy, transparent, and aligned with human values. The organization also conducts research that helps address potential risks and challenges associated with AI, such as safety, security, and ethical concerns.

# %%
completion
# Out:
# <OpenAIObject chat.completion id=chatcmpl-72hFV9kiV5iccTik9scbwzzzMPdMd at 0x213cebb5720> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "OpenAI is an artificial intelligence (AI) research laboratory consisting of the world's leading AI researchers, engineers, and computer scientists. It was founded in December 2015 by a group of entrepreneurs, including Tesla CEO Elon Musk, with the aim of developing technologies that can benefit humanity in a safe and beneficial manner. OpenAI focuses on research in various areas of AI, ranging from natural language processing to robotics, and aims to develop AI systems that are trustworthy, transparent, and aligned with human values. The organization also conducts research that helps address potential risks and challenges associated with AI, such as safety, security, and ethical concerns.",
#         "role": "assistant"
#       }
#     }
#   ],
# ...

# %% [markdown]
# ### https://blog.devgenius.io/chatgpt-how-to-use-it-with-python-5d729ac34c0d

# %%
# Set up the model and prompt
model_engine = "text-davinci-003"
prompt = "Once upon a time, in a land far, far away, there was a princess who..."

# Generate a response
completion = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

response = completion.choices[0].text
print(response)
# Out:
# lived in a castle surrounded by a vast kingdom. She was beloved by her people, and they all looked to her for guidance and strength. Every day, she would go out into the kingdom and help those in need, whether it be providing food to the hungry or shelter to the homeless. She was a great leader and her people respected her greatly.
#
# One day, a mysterious stranger arrived in the kingdom. He was tall and handsome, with a mysterious air about him. He asked to meet the princess and she agreed to do so. When they met, the stranger told the princess of a powerful magical artifact that could grant any wish she desired. He said that if she could find it, she could use it to bring peace and prosperity to her kingdom.
#
# ...
